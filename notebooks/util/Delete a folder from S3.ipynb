# %%
import sys
import boto3
from awsglue.utils import getResolvedOptions
import pyspark.sql.functions as F
from pyspark import SparkContext
from awsglue.context import GlueContext
from awsglue.dynamicframe import DynamicFrame
from awsglue.job import Job
from pyspark.sql.functions import col, max
from pyspark.sql.types import StringType
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>application_1650977892719_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-10-70.eu-west-2.compute.internal:20888/proxy/application_1650977892719_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-3-34.eu-west-2.compute.internal:8042/node/containerlogs/container_1650977892719_0002_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('dataplatform-stg-trusted-zone')
bucket.objects.filter(Prefix="planning/tascomi_tables/applications_reporting/").delete()

# # from helpers import get_glue_env_var, PARTITION_KEYS

# glueContext = GlueContext(SparkContext.getOrCreate())
# job = Job(glueContext)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# [{'ResponseMetadata': {'RequestId': 'XPA69Q2EQAKE3PEK', 'HostId': '/Gb4jQRc2JOkBBbLNqLtoKvcBnumZY12SUJiOEII/hxA0/3cIOOznAmpIlEWiWS/+R/1fcAk378=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '/Gb4jQRc2JOkBBbLNqLtoKvcBnumZY12SUJiOEII/hxA0/3cIOOznAmpIlEWiWS/+R/1fcAk378=', 'x-amz-request-id': 'XPA69Q2EQAKE3PEK', 'date': 'Tue, 26 Apr 2022 16:18:17 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'planning/tascomi_tables/applications_reporting/snapshot_year=2022/snapshot_month=04/snapshot_day=23/snapshot_date=20220423/part-00043-2060f718-6562-4a78-86b0-bf0acede2377.c000.snappy.parquet'}, {'Key': 'planning/tascomi_tables/applications_reporting/snapshot_year=2022/snapshot_month=04/snapshot_day=26/snapshot_date=20220426/part-00058-7e48fbe6-7f6f-487c-855b-a859c61977ba.c000.snappy.parquet'}, {'Key': 'planning/tascomi_tables/applications_reporting/snapshot_year=2022/snapshot_month=04/snapshot_day=26/snapshot_date=20220426/part-00116-7e48fbe6-7f6f-487c-855b-a859c61977ba.c000.snappy.parquet'}, {'Key': 'planning/tascomi_tables/applications_reporting/snapshot_year=2022/snapshot_month=04/snapshot_day=23/snapshot_date=20220423/part-00175-fdac0cbc-20fd-4d1e-8325-37c276d79679.c000.snappy.parquet'}, {'Key': 'planning/tascomi_tables/applications_reporting/snapshot_year=2022/snapshot_month=04/snapshot_day=24/snapshot_date=20220424/part-00037-152e5925-d5ec-4c